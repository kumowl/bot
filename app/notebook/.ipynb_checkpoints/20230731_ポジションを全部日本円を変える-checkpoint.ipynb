# %% [markdown]
# ### ポジションを全部日本円に変えるノートブック

# %% [markdown]
# 成り行き注文で全てのポジションを日本円に変える．

# %%
import sys
sys.path.append('../')
import os

# %%
import json
import pandas as pd

#自作モジュール
from gmo_api import GmoApi_private

# %%
# config.jsonの読み込み
with open("../config.json", 'r') as f:
    config = json.load(f)

apiKey    = config['GMO_API_KEY']
secretKey = config['GMO_API_SECRET']
symbols = config['symbols']

gmo_api_private = GmoApi_private(apiKey, secretKey)

BASE_DIR = '../data/historical_klines/'

# %%
position_df = pd.DataFrame(gmo_api_private.get_balance()['data'])
position_df[['amount', 'available', 'conversionRate']] = position_df[['amount', 'available', 'conversionRate']].astype(float)
position_df
# Out:
#       amount  available  conversionRate symbol
# 0   118921.0   118921.0    1.000000e+00    JPY
# 1        0.0        0.0    4.079964e+06    BTC
# 2        0.0        0.0    2.571700e+05    ETH
# 3        0.0        0.0    3.205100e+04    BCH
# 4        0.0        0.0    1.227800e+04    LTC
# 5        0.0        0.0    9.543700e+01    XRP
# 6        0.0        0.0    4.375000e+00    XEM
# 7       10.0       10.0    1.987200e+01    XLM
# 8       33.0       33.0    2.782100e+01    BAT
# 9        0.0        0.0    7.917947e+01    OMG
# 10       0.0        0.0    1.157670e+02    XTZ
# 11       2.3        2.3    3.774460e+02   QTUM
# 12       0.0        0.0    3.996200e+01    ENJ
# 13       0.0        0.0    6.950000e+02    DOT
# 14       0.0        0.0    1.186000e+03   ATOM
# 15       0.0        0.0    1.809030e+05    MKR
# 16       0.0        0.0    1.429800e+02    DAI
# 17     239.0      239.0    4.134000e+00    XYM
# 18      14.0       14.0    6.950000e+01   MONA
# 19       0.0        0.0    2.990000e-01    FCR
# 20       0.0        0.0    4.084900e+01    ADA
# 21       0.0        0.0    1.014000e+03   LINK
# 22       0.0        0.0    1.015600e+01   DOGE
# 23       0.0        0.0    3.081000e+03    SOL
# 24       0.0        0.0    2.085270e+00    FLR
# 25       0.0        0.0    7.383000e+00   ASTR
# 26       0.0        0.0    5.893050e+02    FIL
# 27       0.0        0.0    5.790600e+01   SAND
# 28       0.0        0.0    1.056400e+01    CHZ

# %%
for symbol in symbols:
    size = position_df.loc[position_df['symbol'] == symbol]['amount'].values[0]
    gmo_api_private.post_order(symbol = symbol, side = 'SELL', executionType = 'MARKET', size = size)
